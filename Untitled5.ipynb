# %%
L=load("44mat7.sobj")
for i in range(44):
    print(i)
    print(L[i])
    print("________________")
# Out:
# 0
# [ 2  2  2  2  2  2  1]
# [ 2  2  2 -2 -2 -1 -2]
# [ 2 -2 -1  2 -2  2 -2]
# [ 1  2 -2  2 -2 -2  2]
# [ 2 -3  2  0  0 -2  2]
# [ 2  0 -2 -3  0  2  2]
# [ 2  0 -2  0  3 -2 -2]
# ________________
# 1
# [ 2  2  2  2  2  2  1]
# [ 2  2  2 -2 -2 -1 -2]
# [ 3 -2 -2  0  0  2 -2]
# [ 2 -3  2  0  0 -2  2]
# [ 2  2 -3  0  0 -2  2]
# [ 0  0  0  4 -1 -2 -2]
# [ 0  0  0  1 -4  2  2]
# ________________
# 2
# [ 2  2  2  2  2  2  1]
# [ 3  2 -2 -2  0  0 -2]
# [ 2 -3 -2  0  2  0  2]
# [ 2 -2  3  0  0 -2 -2]
# [ 2  0  0  1 -4  0  2]
# [ 0  2  0  0  1 -4  2]
# [ 0  0  2 -4  0  1  2]
# ________________
# 3
# [ 2  2  2  2  2  2  1]
# [ 3 -3  1  1 -1  0 -2]
# [ 3  1 -3  0 -1 -1  2]
# [ 1  1 -1 -3  0  3 -2]
# [ 1  1  0 -1  3 -3 -2]
# [ 1  0  3 -3 -1 -1  2]
# [ 0  3  1  1 -3 -1 -2]
# ________________
# 4
# [ 2  2  2  2  2  2  1]
# [ 3 -3  1  1 -1  0 -2]
# [ 3  1 -1 -1  0 -3  2]
# [ 1  0 -1 -1 -3  3  2]
# [ 0  3  1  1 -3 -1 -2]
# [ 1  1 -4  1  1  1 -2]
# [ 1  1  1 -4  1  1 -2]
# ________________
# 5
# ...

# %%
O=[]
