# %%
# File Name: SageCheckIWnkViaILPAgainstSignedPermutationsDate29082022Ver01.txt
# Purpose: Check (Integer) Weighing matrices Via Integer Linear Programming against (direct) Signed permutations
# Remark: After session with Radi. We are left with a question:
#         Why No solution for R1,R2:  [0, 0, 0, 0, 0, 0, 5] [0, 0, 2, 2, 2, 2, 3]
# Improvements: (1) Problem from remark fixed.
#               (2) Added "sors" routine from Assaf, so to generalize the whole activity.
# Remark: Radi on 8/5/22 noticed that solutions begin with negative values although BegWithPos should prevent it.
#         We fix it.
# Remark: On 12/5/22 we added two routines
#         OurMain2: Given parameters of weighing matrix, weight and 2 divisors of order, it gives all pairs of
#                   orthogonal rows of all types available of nsoks and filter them by the code invariany method.
#         AddLine:  Given Nsoks and Sols gives all additions to Sols by one row taken from Nsoks
#                   with permutations and signings and codeinvariant.
#                   This routine is the basis for recursion to construct all Integer Weighing Matrices.
#                   We have not run and debugged this routine yet. Next time...
# Remark: On 15/5/22 we wroteqimproved/touched some routines:
#         OurMain2: This is the new main. It gets the [WMweight, WMOrderDiv] of a weighing matrix and should output all inequivalent Integer weighing matrices of order=WMOrderDiv & weight=sqrt(WMweight. 
#         FilterOrthogonalSignedPermutationsAgainstMatrix (haven't debugged yet)
#         CodePrevRows (debugged carefully)
# Remark: On 26052022 we debuged OurMain2 routine.
# Remark On 30-6-22 Organizing the hp check. 
#                   automatic base calculation for the code invariant
#                   indexing the permutation and signs and saving the index in the configuration.
# Remark on 3-7-22 Adding code to check for Hadamrd equivalnce for two rows for permutation AND row negation
#                  Changes in "FilterOrthogonalSignedPermutationsByCodeInvariant" adding two code invariants for each line.
# Remark on 14-7-22 Adding the index for each line of (NsoksIndex,PermutationIndex,SignsIndex) 
#                    Bug for line [3, 2, 2, 2, 2, 0, 0], [[1, 16, 5], (2, -3, 2, -2, 0, 2, 0)]], 
#                                 The SignsIndex looks incorrect - TBD in the next meeting
# Remark on 21-7-22 Generelizing for AboveMatrix.
#                    -   OrthogonalSignedPermutationsWithFirstNonZeroPositiveAgainstMatrix
#                    -   normAboveAgainstMatrix(AboveMatrix,R2):
#                    -   dpAgainstMatrix
#                       need to correct FilterOrthogonalSignedPermutationsByCodeInvariantAgainstMatrix
# Remark on 24-7-22  began adapting FilterOrthogonalSignedPermutationsByCodeInvariantAgainstMatrix
#                    adding routine genCode for generating a code for the column i.
#                   for next time - continue to adapt  FilterOrthogonalSignedPermutationsByCodeInvariantAgainstMatrix
#                                    and remove CodePrevRows
# Remark on 31-7-22 remove CodePrevTows and AddLine
#                   Checked FilterOrthogonalSignedPermutationsByCodeInvariantAgainstMatrix for addition of one row.
#                   Coded OurMain3 to work with FilterOrthogonalSignedPermutationsByCodeInvariantAgainstMatrix
#                   Checked OurMain3 for two lines.
# Remark on 31-7-22 Adapt OurMain3 for 7 lines
#                   While running OurMain3 it works fine for 2 and 3 lines but crashes while
#                             calculating for 4 lines in memory shortage
# Remark on 18-7-22 Cleanup
# Remark on 28-8-22 
#                  integrate   FilterOrthogonalSignedPermutationsByCodeInvariant
#                           to OrthogonalSignedPermutationsWithFirstNonZeroPositiveAgainstMatrix
#                  integrate hp into OrthogonalSignedPermutationsWithFirstNonZeroPositiveAgainstMatrix
#                  integrate gencode also
#                  add goodPerm test to eliminate (-1) assignment to 0 (faster)


def HadamardSpace(d):
    SpaceSize = 2^d
    L=[ZZ(n).digits(2) for n in range(SpaceSize)]
    L1 = [x+[0]*(d-len(x)) for x in L]
    return([vector([2*y-1 for y in x]) for x in L1])

def IsBegWithPos(L):
    for x in L:
        if x>0:
            return(True)
        if x<0:
            return(False)
    return(False)

def goodPerm(L,s):
    for i in range(len(L)):
        if (L[i]==0) and (s[i]==-1) : return false
    return true

def normAboveAgainstMatrix(AboveMatrix,R2):
    for i in range(len(R2)):
        if AboveMatrix.column(i).norm()==0:
            R2[i]=abs(R2[i])
    return R2


def dpAgainstMatrix(AboveMatrix,L2):
    return((AboveMatrix*vector(L2)).norm())


def OrthogonalSignedPermutationsWithFirstNonZeroPositiveAgainstMatrix(AboveMat,L,Lindex,MaxV):
    P = Permutations(L).list()
    d = len(L)
    S = HadamardSpace(d)
    SP = []
    s = []
    sd = [] 
    codeBase = 1+2*MaxV
    nR=AboveMat.nrows()
    cB=(vector([codeBase^(nR-j) for j in range(nR)]))*AboveMat
    for pi in range(Lindex[1],len(P)):
        p = P[pi]
        s0=Lindex[2] if pi==Lindex[1] else 0
        for si in range(s0,len(S)):
            sn=S[si]
            if (goodPerm(p,sn)):
                r =[p[i]*sn[i] for i in range(d)]
                if IsBegWithPos(r):
                    if dpAgainstMatrix(AboveMat,r)==0:
                        r=normAboveAgainstMatrix(AboveMat,r)
                        if not(r in SP):
                            SP.append(r)
                            R2i=vector(r)
                            M1 = cB+R2i
                            M1s = sorted(M1)
                            if not(M1s in s) :
                                M1m = cB-R2i
                                M1sm = sorted(M1m)
                                if not(M1sm in s):
                                    s.append(M1s)
                                    sd.append([[Lindex[0],pi,si],R2i])                    
    return(sd)



def sors(n,r,maxsq):  ### Find all ways to express n=\sum_i s_i^2 as a sum of r squares, with maxsq>=s_1>=s_2>=...>=s_r.
    #n0=RDF(n)
    n0=n
    if r==1:
        s=sqrt(n0)
        fs=floor(s)
        if s==fs and s<=maxsq:
            return [[s]]
        else:
            return false
    else:
        sors2=[]
        for x in range(floor(sqrt(n0/r)),min(floor(sqrt(n0)),maxsq)+1):
            m=n-x^2
            #print x
            sors1=sors(m,r-1,x)
            if sors1:
                sors2+=[[x]+sors1[i] for i in range(len(sors1))   ]
           # print "sors2=",sors2
        if len(sors2)>0:
            return sors2
        else:
            return false


def OurMain3(WMWeight, WMOrderDiv,lines):
    MaxSquare = WMWeight^(1/2)
    AllSoks = sors(WMWeight, WMOrderDiv, MaxSquare)
    print("Nsoks: ",AllSoks)
    Sols= [[matrix(1,WMOrderDiv,AllSoks[i]),[i,0,0]] for i in range(len(AllSoks))]
    print(Sols)
    for line in range(lines-1):
        nSols=[]
        countSol=0
        countScan=0
        for Sol in Sols:
            countScan+=1
            AboveMat=Sol[0]
            R1Index=Sol[1]
            for R2i in range(R1Index[0],len(AllSoks)):
                R2Index=R1Index if R2i==R1Index[0] else [R2i,0,0]
                R2 = vector(AllSoks[R2i])
                cpF = OrthogonalSignedPermutationsWithFirstNonZeroPositiveAgainstMatrix(AboveMat,R2,R2Index,MaxSquare)
                countSol+=len(cpF)
                if len(cpF)>0:
                    nSols.extend([AboveMat,x] for x in cpF)
            print("countScan,countSol  = ",countScan,countSol)
        Sols=[]
        for nSol in nSols:
            NL=matrix(WMOrderDiv,1,list(nSol[1][1]))
            AM=((nSol[0].transpose()).augment(NL)).transpose()
            Sols.append([AM,nSol[1][0]])
        print("# of sols in line",line, "  =",len(Sols),[Sols[i] for i in range(min(len(Sols),3))])
    return(Sols)

from gc import collect
collect()
# %time res=OurMain3(24,7,7)
# Out:
# Nsoks:  [[2, 2, 2, 2, 2, 2, 0], [3, 2, 2, 2, 1, 1, 1], [3, 3, 2, 1, 1, 0, 0], [4, 2, 1, 1, 1, 1, 0], [4, 2, 2, 0, 0, 0, 0]]
# [[[2 2 2 2 2 2 0], [0, 0, 0]], [[3 2 2 2 1 1 1], [1, 0, 0]], [[3 3 2 1 1 0 0], [2, 0, 0]], [[4 2 1 1 1 1 0], [3, 0, 0]], [[4 2 2 0 0 0 0], [4, 0, 0]]]
# countScan,countSol  =  1 14
# countScan,countSol  =  2 70
# countScan,countSol  =  3 127
# countScan,countSol  =  4 144
# countScan,countSol  =  5 147
# # of sols in line 0   = 147 [[[ 2  2  2  2  2  2  0]
# [ 2  2  2 -2 -2 -2  0], [0, 0, 71]], [[ 2  2  2  2  2  2  0]
# [ 3  2 -2 -1 -1 -1  2], [1, 3, 3]], [[ 2  2  2  2  2  2  0]
# [ 3 -2 -2  1  1 -1  2], [1, 3, 25]]]
# countScan,countSol  =  1 20
# countScan,countSol  =  2 38
# countScan,countSol  =  3 67
# countScan,countSol  =  4 96
# countScan,countSol  =  5 112
# countScan,countSol  =  6 126
# countScan,countSol  =  7 158
# countScan,countSol  =  8 163
# countScan,countSol  =  9 166
# countScan,countSol  =  10 170
# countScan,countSol  =  11 173
# countScan,countSol  =  12 177
# countScan,countSol  =  13 180
# countScan,countSol  =  14 181
# countScan,countSol  =  15 200
# countScan,countSol  =  16 230
# countScan,countSol  =  17 260
# countScan,countSol  =  18 308
# countScan,countSol  =  19 354
# countScan,countSol  =  20 381
# countScan,countSol  =  21 409
# countScan,countSol  =  22 454
# countScan,countSol  =  23 479
# countScan,countSol  =  24 501
# countScan,countSol  =  25 525
# countScan,countSol  =  26 563
# countScan,countSol  =  27 590
# countScan,countSol  =  28 637
# countScan,countSol  =  29 660
# countScan,countSol  =  30 681
# countScan,countSol  =  31 703
# countScan,countSol  =  32 723
# countScan,countSol  =  33 744
# countScan,countSol  =  34 784
# countScan,countSol  =  35 805
# countScan,countSol  =  36 826
# countScan,countSol  =  37 849
# countScan,countSol  =  38 877
# countScan,countSol  =  39 896
# countScan,countSol  =  40 904
# countScan,countSol  =  41 924
# countScan,countSol  =  42 938
# countScan,countSol  =  43 951
# countScan,countSol  =  44 970
# countScan,countSol  =  45 992
# countScan,countSol  =  46 1004
# countScan,countSol  =  47 1022
# countScan,countSol  =  48 1032
# countScan,countSol  =  49 1045
# countScan,countSol  =  50 1063
# countScan,countSol  =  51 1068
# countScan,countSol  =  52 1072
# countScan,countSol  =  53 1077
# countScan,countSol  =  54 1086
# countScan,countSol  =  55 1094
# countScan,countSol  =  56 1098
# countScan,countSol  =  57 1109
# countScan,countSol  =  58 1116
# countScan,countSol  =  59 1122
# countScan,countSol  =  60 1130
# countScan,countSol  =  61 1138
# countScan,countSol  =  62 1142
# countScan,countSol  =  63 1145
# countScan,countSol  =  64 1150
# countScan,countSol  =  65 1151
# countScan,countSol  =  66 1151
# countScan,countSol  =  67 1152
# countScan,countSol  =  68 1154
# countScan,countSol  =  69 1155
# countScan,countSol  =  70 1155
# countScan,countSol  =  71 1171
# countScan,countSol  =  72 1187
# countScan,countSol  =  73 1219
# countScan,countSol  =  74 1239
# countScan,countSol  =  75 1261
# countScan,countSol  =  76 1283
# countScan,countSol  =  77 1302
# countScan,countSol  =  78 1322
# countScan,countSol  =  79 1341
# countScan,countSol  =  80 1362
# countScan,countSol  =  81 1376
# countScan,countSol  =  82 1386
# countScan,countSol  =  83 1404
# countScan,countSol  =  84 1414
# countScan,countSol  =  85 1422
# countScan,countSol  =  86 1429
# countScan,countSol  =  87 1446
# countScan,countSol  =  88 1454
# countScan,countSol  =  89 1469
# countScan,countSol  =  90 1474
# countScan,countSol  =  91 1480
# countScan,countSol  =  92 1497
# countScan,countSol  =  93 1512
# countScan,countSol  =  94 1518
# countScan,countSol  =  95 1524
# countScan,countSol  =  96 1528
# countScan,countSol  =  97 1539
# countScan,countSol  =  98 1544
# countScan,countSol  =  99 1549
# countScan,countSol  =  100 1554
# countScan,countSol  =  101 1565
# countScan,countSol  =  102 1571
# countScan,countSol  =  103 1591
# countScan,countSol  =  104 1600
# countScan,countSol  =  105 1604
# countScan,countSol  =  106 1608
# countScan,countSol  =  107 1624
# countScan,countSol  =  108 1632
# countScan,countSol  =  109 1635
# countScan,countSol  =  110 1639
# countScan,countSol  =  111 1645
# countScan,countSol  =  112 1651
# countScan,countSol  =  113 1659
# countScan,countSol  =  114 1663
# countScan,countSol  =  115 1667
# countScan,countSol  =  116 1673
# countScan,countSol  =  117 1678
# countScan,countSol  =  118 1683
# countScan,countSol  =  119 1685
# countScan,countSol  =  120 1696
# countScan,countSol  =  121 1699
# countScan,countSol  =  122 1704
# countScan,countSol  =  123 1706
# countScan,countSol  =  124 1707
# countScan,countSol  =  125 1707
# countScan,countSol  =  126 1709
# countScan,countSol  =  127 1709
# countScan,countSol  =  128 1715
# countScan,countSol  =  129 1728
# countScan,countSol  =  130 1739
# countScan,countSol  =  131 1742
# countScan,countSol  =  132 1747
# countScan,countSol  =  133 1757
# countScan,countSol  =  134 1760
# countScan,countSol  =  135 1769
# countScan,countSol  =  136 1774
# countScan,countSol  =  137 1778
# countScan,countSol  =  138 1783
# countScan,countSol  =  139 1788
# countScan,countSol  =  140 1789
# countScan,countSol  =  141 1791
# countScan,countSol  =  142 1794
# countScan,countSol  =  143 1795
# countScan,countSol  =  144 1795
# countScan,countSol  =  145 1798
# countScan,countSol  =  146 1799
# countScan,countSol  =  147 1801
# # of sols in line 1   = 1801 [[[ 2  2  2  2  2  2  0]
# [ 2  2  2 -2 -2 -2  0]
# [ 3 -2 -1  2 -1 -1  2], [1, 6, 9]], [[ 2  2  2  2  2  2  0]
# [ 2  2  2 -2 -2 -2  0]
# [ 3 -2 -1 -2  1  1  2], [1, 6, 49]], [[ 2  2  2  2  2  2  0]
# [ 2  2  2 -2 -2 -2  0]
# [ 2 -3  1  2 -1 -1  2], [1, 26, 13]]]
# countScan,countSol  =  1 9
# countScan,countSol  =  2 18
# countScan,countSol  =  3 26
# countScan,countSol  =  4 34
# countScan,countSol  =  5 43
# countScan,countSol  =  6 52
# countScan,countSol  =  7 61
# countScan,countSol  =  8 70
# countScan,countSol  =  9 79
# countScan,countSol  =  10 85
# countScan,countSol  =  11 93
# countScan,countSol  =  12 99
# countScan,countSol  =  13 100
# countScan,countSol  =  14 101
# countScan,countSol  =  15 102
# countScan,countSol  =  16 103
# countScan,countSol  =  17 106
# countScan,countSol  =  18 107
# countScan,countSol  =  19 108
# countScan,countSol  =  20 108
# countScan,countSol  =  21 115
# countScan,countSol  =  22 116
# countScan,countSol  =  23 117
# countScan,countSol  =  24 124
# countScan,countSol  =  25 125
# countScan,countSol  =  26 126
# countScan,countSol  =  27 126
# countScan,countSol  =  28 127
# countScan,countSol  =  29 127
# countScan,countSol  =  30 127
# countScan,countSol  =  31 128
# countScan,countSol  =  32 128
# countScan,countSol  =  33 129
# countScan,countSol  =  34 130
# countScan,countSol  =  35 130
# countScan,countSol  =  36 130
# countScan,countSol  =  37 131
# countScan,countSol  =  38 131
# countScan,countSol  =  39 133
# countScan,countSol  =  40 135
# countScan,countSol  =  41 137
# countScan,countSol  =  42 139
# countScan,countSol  =  43 140
# countScan,countSol  =  44 141
# countScan,countSol  =  45 150
# countScan,countSol  =  46 151
# countScan,countSol  =  47 152
# countScan,countSol  =  48 154
# countScan,countSol  =  49 159
# countScan,countSol  =  50 160
# countScan,countSol  =  51 161
# countScan,countSol  =  52 162
# countScan,countSol  =  53 162
# countScan,countSol  =  54 165
# countScan,countSol  =  55 167
# countScan,countSol  =  56 167
# countScan,countSol  =  57 168
# countScan,countSol  =  58 169
# countScan,countSol  =  59 169
# countScan,countSol  =  60 170
# countScan,countSol  =  61 171
# countScan,countSol  =  62 172
# countScan,countSol  =  63 172
# countScan,countSol  =  64 172
# countScan,countSol  =  65 172
# countScan,countSol  =  66 173
# countScan,countSol  =  67 173
# countScan,countSol  =  68 183
# countScan,countSol  =  69 185
# countScan,countSol  =  70 186
# countScan,countSol  =  71 188
# countScan,countSol  =  72 190
# countScan,countSol  =  73 191
# countScan,countSol  =  74 192
# countScan,countSol  =  75 193
# countScan,countSol  =  76 194
# countScan,countSol  =  77 195
# countScan,countSol  =  78 196
# countScan,countSol  =  79 197
# countScan,countSol  =  80 197
# countScan,countSol  =  81 198
# countScan,countSol  =  82 200
# countScan,countSol  =  83 202
# countScan,countSol  =  84 206
# countScan,countSol  =  85 209
# countScan,countSol  =  86 211
# countScan,countSol  =  87 212
# countScan,countSol  =  88 212
# countScan,countSol  =  89 213
# countScan,countSol  =  90 214
# countScan,countSol  =  91 215
# countScan,countSol  =  92 215
# countScan,countSol  =  93 215
# countScan,countSol  =  94 215
# countScan,countSol  =  95 216
# countScan,countSol  =  96 216
# countScan,countSol  =  97 222
# countScan,countSol  =  98 227
# countScan,countSol  =  99 228
# countScan,countSol  =  100 229
# countScan,countSol  =  101 229
# countScan,countSol  =  102 230
# countScan,countSol  =  103 230
# countScan,countSol  =  104 230
# countScan,countSol  =  105 230
# countScan,countSol  =  106 231
# countScan,countSol  =  107 232
# countScan,countSol  =  108 233
# countScan,countSol  =  109 233
# countScan,countSol  =  110 234
# countScan,countSol  =  111 234
# countScan,countSol  =  112 234
# countScan,countSol  =  113 235
# countScan,countSol  =  114 237
# countScan,countSol  =  115 239
# countScan,countSol  =  116 240
# countScan,countSol  =  117 242
# countScan,countSol  =  118 244
# countScan,countSol  =  119 246
# countScan,countSol  =  120 248
# countScan,countSol  =  121 249
# countScan,countSol  =  122 249
# countScan,countSol  =  123 249
# countScan,countSol  =  124 249
# countScan,countSol  =  125 250
# countScan,countSol  =  126 250
# countScan,countSol  =  127 251
# countScan,countSol  =  128 255
# countScan,countSol  =  129 256
# countScan,countSol  =  130 257
# countScan,countSol  =  131 261
# countScan,countSol  =  132 262
# countScan,countSol  =  133 263
# countScan,countSol  =  134 264
# countScan,countSol  =  135 265
# countScan,countSol  =  136 266
# countScan,countSol  =  137 268
# countScan,countSol  =  138 269
# countScan,countSol  =  139 270
# countScan,countSol  =  140 270
# countScan,countSol  =  141 270
# countScan,countSol  =  142 270
# countScan,countSol  =  143 271
# countScan,countSol  =  144 271
# countScan,countSol  =  145 271
# countScan,countSol  =  146 272
# countScan,countSol  =  147 274
# countScan,countSol  =  148 275
# countScan,countSol  =  149 275
# countScan,countSol  =  150 276
# countScan,countSol  =  151 276
# countScan,countSol  =  152 276
# countScan,countSol  =  153 277
# countScan,countSol  =  154 278
# countScan,countSol  =  155 278
# countScan,countSol  =  156 279
# countScan,countSol  =  157 279
# countScan,countSol  =  158 279
# countScan,countSol  =  159 280
# countScan,countSol  =  160 282
# countScan,countSol  =  161 284
# countScan,countSol  =  162 285
# countScan,countSol  =  163 285
# countScan,countSol  =  164 287
# countScan,countSol  =  165 288
# countScan,countSol  =  166 288
# countScan,countSol  =  167 289
# countScan,countSol  =  168 290
# countScan,countSol  =  169 290
# countScan,countSol  =  170 290
# countScan,countSol  =  171 292
# countScan,countSol  =  172 293
# countScan,countSol  =  173 294
# countScan,countSol  =  174 295
# countScan,countSol  =  175 296
# countScan,countSol  =  176 296
# countScan,countSol  =  177 296
# countScan,countSol  =  178 297
# countScan,countSol  =  179 298
# countScan,countSol  =  180 298
# countScan,countSol  =  181 298
# countScan,countSol  =  182 307
# countScan,countSol  =  183 316
# countScan,countSol  =  184 324
# countScan,countSol  =  185 332
# countScan,countSol  =  186 340
# countScan,countSol  =  187 348
# countScan,countSol  =  188 355
# countScan,countSol  =  189 361
# countScan,countSol  =  190 366
# countScan,countSol  =  191 371
# countScan,countSol  =  192 381
# countScan,countSol  =  193 386
# countScan,countSol  =  194 389
# countScan,countSol  =  195 392
# countScan,countSol  =  196 395
# countScan,countSol  =  197 397
# countScan,countSol  =  198 399
# countScan,countSol  =  199 400
# countScan,countSol  =  200 400
# countScan,countSol  =  201 402
# countScan,countSol  =  202 404
# countScan,countSol  =  203 406
# countScan,countSol  =  204 415
# countScan,countSol  =  205 423
# countScan,countSol  =  206 432
# countScan,countSol  =  207 439
# countScan,countSol  =  208 440
# countScan,countSol  =  209 441
# countScan,countSol  =  210 442
# countScan,countSol  =  211 443
# countScan,countSol  =  212 443
# countScan,countSol  =  213 444
# countScan,countSol  =  214 444
# countScan,countSol  =  215 445
# countScan,countSol  =  216 446
# countScan,countSol  =  217 447
# countScan,countSol  =  218 447
# countScan,countSol  =  219 448
# countScan,countSol  =  220 449
# countScan,countSol  =  221 450
# countScan,countSol  =  222 451
# countScan,countSol  =  223 451
# countScan,countSol  =  224 451
# countScan,countSol  =  225 452
# countScan,countSol  =  226 452
# countScan,countSol  =  227 452
# countScan,countSol  =  228 452
# countScan,countSol  =  229 452
# countScan,countSol  =  230 452
# countScan,countSol  =  231 454
# countScan,countSol  =  232 456
# countScan,countSol  =  233 458
# countScan,countSol  =  234 467
# countScan,countSol  =  235 477
# countScan,countSol  =  236 484
# countScan,countSol  =  237 492
# countScan,countSol  =  238 493
# countScan,countSol  =  239 494
# countScan,countSol  =  240 495
# countScan,countSol  =  241 496
# countScan,countSol  =  242 496
# countScan,countSol  =  243 497
# countScan,countSol  =  244 497
# countScan,countSol  =  245 498
# countScan,countSol  =  246 499
# countScan,countSol  =  247 499
# countScan,countSol  =  248 500
# countScan,countSol  =  249 501
# countScan,countSol  =  250 502
# countScan,countSol  =  251 503
# countScan,countSol  =  252 504
# countScan,countSol  =  253 504
# countScan,countSol  =  254 504
# countScan,countSol  =  255 505
# countScan,countSol  =  256 505
# countScan,countSol  =  257 505
# countScan,countSol  =  258 505
# countScan,countSol  =  259 505
# countScan,countSol  =  260 505
# countScan,countSol  =  261 507
# countScan,countSol  =  262 508
# countScan,countSol  =  263 510
# countScan,countSol  =  264 534
# countScan,countSol  =  265 535
# countScan,countSol  =  266 537
# countScan,countSol  =  267 538
# countScan,countSol  =  268 547
# countScan,countSol  =  269 556
# countScan,countSol  =  270 557
# countScan,countSol  =  271 558
# countScan,countSol  =  272 559
# countScan,countSol  =  273 560
# countScan,countSol  =  274 562
# countScan,countSol  =  275 563
# countScan,countSol  =  276 564
# countScan,countSol  =  277 565
# countScan,countSol  =  278 565
# countScan,countSol  =  279 569
# countScan,countSol  =  280 570
# countScan,countSol  =  281 575
# countScan,countSol  =  282 577
# countScan,countSol  =  283 578
# countScan,countSol  =  284 579
# countScan,countSol  =  285 580
# countScan,countSol  =  286 585
# countScan,countSol  =  287 586
# countScan,countSol  =  288 586
# countScan,countSol  =  289 587
# countScan,countSol  =  290 588
# countScan,countSol  =  291 588
# countScan,countSol  =  292 590
# countScan,countSol  =  293 590
# countScan,countSol  =  294 593
# countScan,countSol  =  295 594
# countScan,countSol  =  296 595
# countScan,countSol  =  297 595
# countScan,countSol  =  298 595
# countScan,countSol  =  299 596
# countScan,countSol  =  300 596
# countScan,countSol  =  301 596
# countScan,countSol  =  302 596
# countScan,countSol  =  303 596
# countScan,countSol  =  304 596
# countScan,countSol  =  305 596
# countScan,countSol  =  306 596
# countScan,countSol  =  307 596
# countScan,countSol  =  308 596
# countScan,countSol  =  309 598
# countScan,countSol  =  310 599
# countScan,countSol  =  311 609
# countScan,countSol  =  312 619
# countScan,countSol  =  313 620
# countScan,countSol  =  314 622
# countScan,countSol  =  315 643
# countScan,countSol  =  316 644
# countScan,countSol  =  317 645
# countScan,countSol  =  318 647
# countScan,countSol  =  319 648
# countScan,countSol  =  320 649
# countScan,countSol  =  321 650
# countScan,countSol  =  322 651
# countScan,countSol  =  323 652
# countScan,countSol  =  324 654
# countScan,countSol  =  325 655
# countScan,countSol  =  326 660
# countScan,countSol  =  327 661
# countScan,countSol  =  328 663
# countScan,countSol  =  329 669
# countScan,countSol  =  330 671
# countScan,countSol  =  331 672
# countScan,countSol  =  332 672
# countScan,countSol  =  333 674
# countScan,countSol  =  334 674
# countScan,countSol  =  335 677
# countScan,countSol  =  336 677
# countScan,countSol  =  337 678
# countScan,countSol  =  338 679
# countScan,countSol  =  339 680
# countScan,countSol  =  340 681
# countScan,countSol  =  341 682
# countScan,countSol  =  342 682
# countScan,countSol  =  343 683
# countScan,countSol  =  344 683
# countScan,countSol  =  345 683
# countScan,countSol  =  346 683
# countScan,countSol  =  347 683
# countScan,countSol  =  348 683
# countScan,countSol  =  349 683
# countScan,countSol  =  350 683
# countScan,countSol  =  351 683
# countScan,countSol  =  352 683
# countScan,countSol  =  353 683
# countScan,countSol  =  354 683
# countScan,countSol  =  355 690
# countScan,countSol  =  356 699
# countScan,countSol  =  357 700
# countScan,countSol  =  358 701
# countScan,countSol  =  359 702
# countScan,countSol  =  360 703
# countScan,countSol  =  361 703
# countScan,countSol  =  362 704
# countScan,countSol  =  363 705
# countScan,countSol  =  364 706
# countScan,countSol  =  365 706
# countScan,countSol  =  366 707
# countScan,countSol  =  367 708
# countScan,countSol  =  368 709
# countScan,countSol  =  369 709
# countScan,countSol  =  370 710
# countScan,countSol  =  371 712
# countScan,countSol  =  372 712
# countScan,countSol  =  373 713
# countScan,countSol  =  374 714
# countScan,countSol  =  375 714
# countScan,countSol  =  376 714
# countScan,countSol  =  377 714
# countScan,countSol  =  378 714
# countScan,countSol  =  379 714
# countScan,countSol  =  380 714
# countScan,countSol  =  381 714
# countScan,countSol  =  382 722
# countScan,countSol  =  383 723
# countScan,countSol  =  384 732
# countScan,countSol  =  385 733
# countScan,countSol  =  386 734
# countScan,countSol  =  387 735
# countScan,countSol  =  388 736
# countScan,countSol  =  389 737
# countScan,countSol  =  390 738
# countScan,countSol  =  391 739
# countScan,countSol  =  392 739
# countScan,countSol  =  393 740
# countScan,countSol  =  394 740
# countScan,countSol  =  395 741
# countScan,countSol  =  396 742
# countScan,countSol  =  397 742
# countScan,countSol  =  398 743
# countScan,countSol  =  399 743
# countScan,countSol  =  400 743
# countScan,countSol  =  401 745
# countScan,countSol  =  402 746
# countScan,countSol  =  403 747
# countScan,countSol  =  404 747
# countScan,countSol  =  405 747
# countScan,countSol  =  406 747
# countScan,countSol  =  407 747
# countScan,countSol  =  408 747
# countScan,countSol  =  409 747
# countScan,countSol  =  410 749
# countScan,countSol  =  411 750
# countScan,countSol  =  412 751
# countScan,countSol  =  413 752
# countScan,countSol  =  414 761
# countScan,countSol  =  415 769
# countScan,countSol  =  416 770
# countScan,countSol  =  417 772
# countScan,countSol  =  418 773
# countScan,countSol  =  419 775
# countScan,countSol  =  420 776
# countScan,countSol  =  421 777
# countScan,countSol  =  422 778
# countScan,countSol  =  423 779
# countScan,countSol  =  424 780
# countScan,countSol  =  425 784
# countScan,countSol  =  426 786
# countScan,countSol  =  427 791
# countScan,countSol  =  428 791
# countScan,countSol  =  429 792
# countScan,countSol  =  430 792
# countScan,countSol  =  431 792
# countScan,countSol  =  432 794
# countScan,countSol  =  433 795
# countScan,countSol  =  434 796
# countScan,countSol  =  435 797
# countScan,countSol  =  436 798
# countScan,countSol  =  437 799
# countScan,countSol  =  438 802
# countScan,countSol  =  439 804
# countScan,countSol  =  440 804
# countScan,countSol  =  441 806
# countScan,countSol  =  442 807
# countScan,countSol  =  443 809
# countScan,countSol  =  444 809
# countScan,countSol  =  445 809
# countScan,countSol  =  446 809
# countScan,countSol  =  447 810
# countScan,countSol  =  448 810
# countScan,countSol  =  449 810
# countScan,countSol  =  450 810
# countScan,countSol  =  451 810
# countScan,countSol  =  452 810
# countScan,countSol  =  453 810
# countScan,countSol  =  454 810
# countScan,countSol  =  455 817
# countScan,countSol  =  456 819
# countScan,countSol  =  457 820
# countScan,countSol  =  458 821
# countScan,countSol  =  459 822
# countScan,countSol  =  460 824
# countScan,countSol  =  461 830
# countScan,countSol  =  462 833
# countScan,countSol  =  463 834
# countScan,countSol  =  464 835
# countScan,countSol  =  465 836
# countScan,countSol  =  466 836
# countScan,countSol  =  467 838
# countScan,countSol  =  468 839
# countScan,countSol  =  469 841
# countScan,countSol  =  470 842
# countScan,countSol  =  471 842
# countScan,countSol  =  472 843
# countScan,countSol  =  473 843
# countScan,countSol  =  474 844
# countScan,countSol  =  475 844
# countScan,countSol  =  476 844
# countScan,countSol  =  477 845
# countScan,countSol  =  478 845
# countScan,countSol  =  479 845
# countScan,countSol  =  480 851
# countScan,countSol  =  481 852
# countScan,countSol  =  482 858
# countScan,countSol  =  483 860
# countScan,countSol  =  484 862
# countScan,countSol  =  485 864
# countScan,countSol  =  486 864
# countScan,countSol  =  487 866
# countScan,countSol  =  488 867
# countScan,countSol  =  489 867
# countScan,countSol  =  490 869
# countScan,countSol  =  491 870
# countScan,countSol  =  492 871
# countScan,countSol  =  493 872
# countScan,countSol  =  494 873
# countScan,countSol  =  495 873
# countScan,countSol  =  496 874
# countScan,countSol  =  497 875
# countScan,countSol  =  498 875
# countScan,countSol  =  499 875
# countScan,countSol  =  500 875
# countScan,countSol  =  501 875
# countScan,countSol  =  502 883
# countScan,countSol  =  503 890
# countScan,countSol  =  504 892
# countScan,countSol  =  505 893
# countScan,countSol  =  506 893
# countScan,countSol  =  507 894
# countScan,countSol  =  508 894
# countScan,countSol  =  509 894
# countScan,countSol  =  510 895
# countScan,countSol  =  511 896
# countScan,countSol  =  512 897
# countScan,countSol  =  513 898
# countScan,countSol  =  514 899
# countScan,countSol  =  515 900
# countScan,countSol  =  516 901
# countScan,countSol  =  517 902
# countScan,countSol  =  518 902
# countScan,countSol  =  519 902
# countScan,countSol  =  520 902
# countScan,countSol  =  521 902
# countScan,countSol  =  522 902
# countScan,countSol  =  523 902
# countScan,countSol  =  524 902
# countScan,countSol  =  525 902
# countScan,countSol  =  526 904
# countScan,countSol  =  527 922
# countScan,countSol  =  528 930
# countScan,countSol  =  529 932
# countScan,countSol  =  530 933
# countScan,countSol  =  531 934
# countScan,countSol  =  532 935
# countScan,countSol  =  533 935
# countScan,countSol  =  534 938
# countScan,countSol  =  535 940
# countScan,countSol  =  536 941
# countScan,countSol  =  537 946
# countScan,countSol  =  538 947
# countScan,countSol  =  539 947
# countScan,countSol  =  540 949
# countScan,countSol  =  541 951
# countScan,countSol  =  542 951
# countScan,countSol  =  543 953
# countScan,countSol  =  544 956
# countScan,countSol  =  545 957
# countScan,countSol  =  546 961
# countScan,countSol  =  547 962
# countScan,countSol  =  548 963
# countScan,countSol  =  549 964
# countScan,countSol  =  550 965
# countScan,countSol  =  551 965
# countScan,countSol  =  552 965
# countScan,countSol  =  553 966
# countScan,countSol  =  554 966
# countScan,countSol  =  555 966
# countScan,countSol  =  556 966
# countScan,countSol  =  557 966
# countScan,countSol  =  558 966
# countScan,countSol  =  559 966
# countScan,countSol  =  560 966
# countScan,countSol  =  561 966
# countScan,countSol  =  562 966
# countScan,countSol  =  563 966
# countScan,countSol  =  564 968
# countScan,countSol  =  565 976
# countScan,countSol  =  566 982
# countScan,countSol  =  567 990
# countScan,countSol  =  568 991
# countScan,countSol  =  569 992
# countScan,countSol  =  570 993
# countScan,countSol  =  571 994
# countScan,countSol  =  572 995
# countScan,countSol  =  573 996
# countScan,countSol  =  574 998
# countScan,countSol  =  575 999
# countScan,countSol  =  576 999
# countScan,countSol  =  577 999
# countScan,countSol  =  578 1000
# countScan,countSol  =  579 1001
# countScan,countSol  =  580 1001
# countScan,countSol  =  581 1002
# countScan,countSol  =  582 1003
# countScan,countSol  =  583 1003
# countScan,countSol  =  584 1003
# countScan,countSol  =  585 1003
# countScan,countSol  =  586 1003
# countScan,countSol  =  587 1003
# countScan,countSol  =  588 1003
# countScan,countSol  =  589 1003
# countScan,countSol  =  590 1003
# countScan,countSol  =  591 1009
# countScan,countSol  =  592 1015
# countScan,countSol  =  593 1022
# countScan,countSol  =  594 1029
# countScan,countSol  =  595 1036
# countScan,countSol  =  596 1042
# countScan,countSol  =  597 1048
# countScan,countSol  =  598 1056
# countScan,countSol  =  599 1064
# countScan,countSol  =  600 1069
# countScan,countSol  =  601 1075
# countScan,countSol  =  602 1081
# countScan,countSol  =  603 1088
# countScan,countSol  =  604 1095
# countScan,countSol  =  605 1102
# countScan,countSol  =  606 1106
# countScan,countSol  =  607 1111
# countScan,countSol  =  608 1121
# countScan,countSol  =  609 1126
# countScan,countSol  =  610 1130
# countScan,countSol  =  611 1138
# countScan,countSol  =  612 1141
# countScan,countSol  =  613 1145
# countScan,countSol  =  614 1150
# countScan,countSol  =  615 1153
# countScan,countSol  =  616 1160
# countScan,countSol  =  617 1163
# countScan,countSol  =  618 1168
# countScan,countSol  =  619 1170
# countScan,countSol  =  620 1174
# countScan,countSol  =  621 1178
# countScan,countSol  =  622 1180
# countScan,countSol  =  623 1182
# countScan,countSol  =  624 1184
# countScan,countSol  =  625 1186
# countScan,countSol  =  626 1188
# countScan,countSol  =  627 1188
# countScan,countSol  =  628 1189
# countScan,countSol  =  629 1191
# countScan,countSol  =  630 1193
# countScan,countSol  =  631 1195
# countScan,countSol  =  632 1198
# countScan,countSol  =  633 1199
# countScan,countSol  =  634 1199
# countScan,countSol  =  635 1199
# countScan,countSol  =  636 1200
# countScan,countSol  =  637 1200
# countScan,countSol  =  638 1207
# countScan,countSol  =  639 1208
# countScan,countSol  =  640 1209
# countScan,countSol  =  641 1210
# countScan,countSol  =  642 1210
# countScan,countSol  =  643 1211
# countScan,countSol  =  644 1212
# countScan,countSol  =  645 1212
# countScan,countSol  =  646 1213
# countScan,countSol  =  647 1213
# countScan,countSol  =  648 1213
# countScan,countSol  =  649 1213
# countScan,countSol  =  650 1214
# countScan,countSol  =  651 1215
# countScan,countSol  =  652 1215
# countScan,countSol  =  653 1216
# countScan,countSol  =  654 1217
# countScan,countSol  =  655 1218
# countScan,countSol  =  656 1218
# countScan,countSol  =  657 1219
# countScan,countSol  =  658 1219
# countScan,countSol  =  659 1219
# countScan,countSol  =  660 1219
# countScan,countSol  =  661 1221
# countScan,countSol  =  662 1223
# countScan,countSol  =  663 1224
# countScan,countSol  =  664 1225
# countScan,countSol  =  665 1226
# countScan,countSol  =  666 1227
# countScan,countSol  =  667 1229
# countScan,countSol  =  668 1233
# countScan,countSol  =  669 1233
# countScan,countSol  =  670 1233
# countScan,countSol  =  671 1233
# countScan,countSol  =  672 1235
# countScan,countSol  =  673 1237
# countScan,countSol  =  674 1238
# countScan,countSol  =  675 1238
# countScan,countSol  =  676 1239
# countScan,countSol  =  677 1241
# countScan,countSol  =  678 1241
# countScan,countSol  =  679 1241
# countScan,countSol  =  680 1242
# countScan,countSol  =  681 1242
# countScan,countSol  =  682 1243
# countScan,countSol  =  683 1244
# countScan,countSol  =  684 1245
# countScan,countSol  =  685 1246
# countScan,countSol  =  686 1247
# countScan,countSol  =  687 1247
# countScan,countSol  =  688 1247
# countScan,countSol  =  689 1248
# countScan,countSol  =  690 1248
# countScan,countSol  =  691 1249
# countScan,countSol  =  692 1250
# countScan,countSol  =  693 1251
# countScan,countSol  =  694 1252
# countScan,countSol  =  695 1253
# countScan,countSol  =  696 1253
# countScan,countSol  =  697 1253
# countScan,countSol  =  698 1253
# countScan,countSol  =  699 1253
# countScan,countSol  =  700 1254
# countScan,countSol  =  701 1254
# countScan,countSol  =  702 1254
# countScan,countSol  =  703 1254
# countScan,countSol  =  704 1256
# countScan,countSol  =  705 1258
# countScan,countSol  =  706 1259
# countScan,countSol  =  707 1260
# countScan,countSol  =  708 1261
# countScan,countSol  =  709 1263
# countScan,countSol  =  710 1267
# countScan,countSol  =  711 1267
# countScan,countSol  =  712 1267
# countScan,countSol  =  713 1267
# countScan,countSol  =  714 1270
# countScan,countSol  =  715 1271
# countScan,countSol  =  716 1272
# countScan,countSol  =  717 1272
# countScan,countSol  =  718 1273
# countScan,countSol  =  719 1275
# countScan,countSol  =  720 1275
# countScan,countSol  =  721 1275
# countScan,countSol  =  722 1276
# countScan,countSol  =  723 1276
# countScan,countSol  =  724 1277
# countScan,countSol  =  725 1279
# countScan,countSol  =  726 1281
# countScan,countSol  =  727 1288
# countScan,countSol  =  728 1289
# countScan,countSol  =  729 1291
# countScan,countSol  =  730 1292
# countScan,countSol  =  731 1294
# countScan,countSol  =  732 1294
# countScan,countSol  =  733 1295
# countScan,countSol  =  734 1295
# countScan,countSol  =  735 1297
# countScan,countSol  =  736 1298
# countScan,countSol  =  737 1300
# countScan,countSol  =  738 1300
# countScan,countSol  =  739 1301
# countScan,countSol  =  740 1301
# countScan,countSol  =  741 1301
# countScan,countSol  =  742 1301
# countScan,countSol  =  743 1301
# countScan,countSol  =  744 1301
# countScan,countSol  =  745 1303
# countScan,countSol  =  746 1304
# countScan,countSol  =  747 1306
# countScan,countSol  =  748 1308
# countScan,countSol  =  749 1315
# countScan,countSol  =  750 1316
# countScan,countSol  =  751 1318
# countScan,countSol  =  752 1321
# countScan,countSol  =  753 1322
# countScan,countSol  =  754 1325
# countScan,countSol  =  755 1327
# countScan,countSol  =  756 1329
# countScan,countSol  =  757 1330
# countScan,countSol  =  758 1332
# countScan,countSol  =  759 1334
# countScan,countSol  =  760 1335
# countScan,countSol  =  761 1339
# countScan,countSol  =  762 1339
# countScan,countSol  =  763 1339
# countScan,countSol  =  764 1339
# countScan,countSol  =  765 1342
# countScan,countSol  =  766 1344
# countScan,countSol  =  767 1346
# countScan,countSol  =  768 1347
# countScan,countSol  =  769 1350
# countScan,countSol  =  770 1352
# countScan,countSol  =  771 1353
# countScan,countSol  =  772 1353
# countScan,countSol  =  773 1353
# countScan,countSol  =  774 1353
# countScan,countSol  =  775 1355
# countScan,countSol  =  776 1356
# countScan,countSol  =  777 1356
# countScan,countSol  =  778 1356
# countScan,countSol  =  779 1358
# countScan,countSol  =  780 1358
# countScan,countSol  =  781 1358
# countScan,countSol  =  782 1358
# countScan,countSol  =  783 1358
# countScan,countSol  =  784 1358
# countScan,countSol  =  785 1363
# countScan,countSol  =  786 1366
# countScan,countSol  =  787 1368
# countScan,countSol  =  788 1370
# countScan,countSol  =  789 1375
# countScan,countSol  =  790 1379
# countScan,countSol  =  791 1380
# countScan,countSol  =  792 1384
# countScan,countSol  =  793 1388
# countScan,countSol  =  794 1391
# countScan,countSol  =  795 1393
# countScan,countSol  =  796 1397
# countScan,countSol  =  797 1399
# countScan,countSol  =  798 1401
# countScan,countSol  =  799 1403
# countScan,countSol  =  800 1404
# countScan,countSol  =  801 1404
# countScan,countSol  =  802 1405
# countScan,countSol  =  803 1406
# countScan,countSol  =  804 1406
# countScan,countSol  =  805 1406
# countScan,countSol  =  806 1408
# countScan,countSol  =  807 1408
# countScan,countSol  =  808 1409
# countScan,countSol  =  809 1409
# countScan,countSol  =  810 1415
# countScan,countSol  =  811 1416
# countScan,countSol  =  812 1418
# countScan,countSol  =  813 1419
# countScan,countSol  =  814 1421
# countScan,countSol  =  815 1421
# countScan,countSol  =  816 1423
# countScan,countSol  =  817 1425
# countScan,countSol  =  818 1426
# countScan,countSol  =  819 1427
# countScan,countSol  =  820 1427
# countScan,countSol  =  821 1428
# countScan,countSol  =  822 1429
# countScan,countSol  =  823 1430
# countScan,countSol  =  824 1430
# countScan,countSol  =  825 1430
# countScan,countSol  =  826 1430
# countScan,countSol  =  827 1435
# countScan,countSol  =  828 1436
# countScan,countSol  =  829 1438
# countScan,countSol  =  830 1438
# countScan,countSol  =  831 1438
# countScan,countSol  =  832 1439
# countScan,countSol  =  833 1440
# countScan,countSol  =  834 1441
# countScan,countSol  =  835 1441
# countScan,countSol  =  836 1442
# countScan,countSol  =  837 1442
# countScan,countSol  =  838 1443
# countScan,countSol  =  839 1446
# countScan,countSol  =  840 1446
# countScan,countSol  =  841 1448
# countScan,countSol  =  842 1449
# countScan,countSol  =  843 1449
# countScan,countSol  =  844 1449
# countScan,countSol  =  845 1449
# countScan,countSol  =  846 1449
# countScan,countSol  =  847 1449
# countScan,countSol  =  848 1449
# countScan,countSol  =  849 1449
# countScan,countSol  =  850 1451
# countScan,countSol  =  851 1452
# countScan,countSol  =  852 1453
# countScan,countSol  =  853 1454
# countScan,countSol  =  854 1458
# countScan,countSol  =  855 1458
# countScan,countSol  =  856 1459
# countScan,countSol  =  857 1460
# countScan,countSol  =  858 1464
# countScan,countSol  =  859 1468
# countScan,countSol  =  860 1469
# countScan,countSol  =  861 1470
# countScan,countSol  =  862 1473
# countScan,countSol  =  863 1475
# countScan,countSol  =  864 1476
# countScan,countSol  =  865 1478
# countScan,countSol  =  866 1478
# countScan,countSol  =  867 1479
# countScan,countSol  =  868 1480
# countScan,countSol  =  869 1480
# countScan,countSol  =  870 1480
# countScan,countSol  =  871 1480
# countScan,countSol  =  872 1481
# countScan,countSol  =  873 1481
# countScan,countSol  =  874 1481
# countScan,countSol  =  875 1481
# countScan,countSol  =  876 1482
# countScan,countSol  =  877 1482
# countScan,countSol  =  878 1483
# countScan,countSol  =  879 1483
# countScan,countSol  =  880 1485
# countScan,countSol  =  881 1485
# countScan,countSol  =  882 1487
# countScan,countSol  =  883 1488
# countScan,countSol  =  884 1488
# countScan,countSol  =  885 1489
# countScan,countSol  =  886 1489
# countScan,countSol  =  887 1490
# countScan,countSol  =  888 1493
# countScan,countSol  =  889 1494
# countScan,countSol  =  890 1494
# countScan,countSol  =  891 1494
# countScan,countSol  =  892 1495
# countScan,countSol  =  893 1495
# countScan,countSol  =  894 1495
# countScan,countSol  =  895 1495
# countScan,countSol  =  896 1495
# countScan,countSol  =  897 1496
# countScan,countSol  =  898 1496
# countScan,countSol  =  899 1497
# countScan,countSol  =  900 1498
# countScan,countSol  =  901 1500
# countScan,countSol  =  902 1500
# countScan,countSol  =  903 1500
# countScan,countSol  =  904 1500
# countScan,countSol  =  905 1502
# countScan,countSol  =  906 1505
# countScan,countSol  =  907 1505
# countScan,countSol  =  908 1507
# countScan,countSol  =  909 1508
# countScan,countSol  =  910 1508
# countScan,countSol  =  911 1508
# countScan,countSol  =  912 1509
# countScan,countSol  =  913 1509
# countScan,countSol  =  914 1510
# countScan,countSol  =  915 1512
# countScan,countSol  =  916 1513
# countScan,countSol  =  917 1513
# countScan,countSol  =  918 1513
# countScan,countSol  =  919 1514
# countScan,countSol  =  920 1514
# countScan,countSol  =  921 1514
# countScan,countSol  =  922 1514
# countScan,countSol  =  923 1515
# countScan,countSol  =  924 1515
# countScan,countSol  =  925 1517
# countScan,countSol  =  926 1518
# countScan,countSol  =  927 1518
# countScan,countSol  =  928 1519
# countScan,countSol  =  929 1520
# countScan,countSol  =  930 1521
# countScan,countSol  =  931 1521
# countScan,countSol  =  932 1522
# countScan,countSol  =  933 1524
# countScan,countSol  =  934 1524
# countScan,countSol  =  935 1524
# countScan,countSol  =  936 1524
# countScan,countSol  =  937 1524
# countScan,countSol  =  938 1524
# countScan,countSol  =  939 1528
# countScan,countSol  =  940 1528
# countScan,countSol  =  941 1529
# countScan,countSol  =  942 1530
# countScan,countSol  =  943 1530
# countScan,countSol  =  944 1531
# countScan,countSol  =  945 1533
# countScan,countSol  =  946 1534
# countScan,countSol  =  947 1534
# countScan,countSol  =  948 1534
# countScan,countSol  =  949 1534
# countScan,countSol  =  950 1534
# countScan,countSol  =  951 1534
# countScan,countSol  =  952 1535
# countScan,countSol  =  953 1535
# countScan,countSol  =  954 1536
# countScan,countSol  =  955 1537
# countScan,countSol  =  956 1538
# countScan,countSol  =  957 1538
# countScan,countSol  =  958 1539
# countScan,countSol  =  959 1540
# countScan,countSol  =  960 1540
# countScan,countSol  =  961 1540
# countScan,countSol  =  962 1543
# countScan,countSol  =  963 1545
# countScan,countSol  =  964 1545
# countScan,countSol  =  965 1545
# countScan,countSol  =  966 1545
# countScan,countSol  =  967 1545
# countScan,countSol  =  968 1545
# countScan,countSol  =  969 1545
# countScan,countSol  =  970 1545
# countScan,countSol  =  971 1549
# countScan,countSol  =  972 1549
# countScan,countSol  =  973 1550
# countScan,countSol  =  974 1550
# countScan,countSol  =  975 1551
# countScan,countSol  =  976 1552
# countScan,countSol  =  977 1552
# countScan,countSol  =  978 1553
# countScan,countSol  =  979 1555
# countScan,countSol  =  980 1555
# countScan,countSol  =  981 1558
# countScan,countSol  =  982 1560
# countScan,countSol  =  983 1560
# countScan,countSol  =  984 1561
# countScan,countSol  =  985 1561
# countScan,countSol  =  986 1561
# countScan,countSol  =  987 1561
# countScan,countSol  =  988 1561
# countScan,countSol  =  989 1561
# countScan,countSol  =  990 1562
# countScan,countSol  =  991 1562
# countScan,countSol  =  992 1562
# countScan,countSol  =  993 1564
# countScan,countSol  =  994 1565
# countScan,countSol  =  995 1569
# countScan,countSol  =  996 1572
# countScan,countSol  =  997 1574
# countScan,countSol  =  998 1576
# countScan,countSol  =  999 1579
# countScan,countSol  =  1000 1579
# countScan,countSol  =  1001 1579
# countScan,countSol  =  1002 1579
# countScan,countSol  =  1003 1579
# countScan,countSol  =  1004 1579
# countScan,countSol  =  1005 1581
# countScan,countSol  =  1006 1582
# countScan,countSol  =  1007 1583
# countScan,countSol  =  1008 1584
# countScan,countSol  =  1009 1588
# countScan,countSol  =  1010 1590
# countScan,countSol  =  1011 1593
# countScan,countSol  =  1012 1595
# countScan,countSol  =  1013 1596
# countScan,countSol  =  1014 1597
# countScan,countSol  =  1015 1599
# countScan,countSol  =  1016 1600
# countScan,countSol  =  1017 1600
# countScan,countSol  =  1018 1602
# countScan,countSol  =  1019 1603
# countScan,countSol  =  1020 1603
# countScan,countSol  =  1021 1603
# countScan,countSol  =  1022 1603
# countScan,countSol  =  1023 1604
# countScan,countSol  =  1024 1605
# countScan,countSol  =  1025 1608
# countScan,countSol  =  1026 1609
# countScan,countSol  =  1027 1609
# countScan,countSol  =  1028 1609
# countScan,countSol  =  1029 1609
# countScan,countSol  =  1030 1609
# countScan,countSol  =  1031 1610
# countScan,countSol  =  1032 1610
# countScan,countSol  =  1033 1612
# countScan,countSol  =  1034 1613
# countScan,countSol  =  1035 1614
# countScan,countSol  =  1036 1615
# countScan,countSol  =  1037 1615
# countScan,countSol  =  1038 1616
# countScan,countSol  =  1039 1617
# countScan,countSol  =  1040 1618
# countScan,countSol  =  1041 1618
# countScan,countSol  =  1042 1618
# countScan,countSol  =  1043 1619
# countScan,countSol  =  1044 1619
# countScan,countSol  =  1045 1619
# countScan,countSol  =  1046 1621
# countScan,countSol  =  1047 1622
# countScan,countSol  =  1048 1624
# countScan,countSol  =  1049 1624
# countScan,countSol  =  1050 1624
# countScan,countSol  =  1051 1625
# countScan,countSol  =  1052 1628
# countScan,countSol  =  1053 1629
# countScan,countSol  =  1054 1630
# countScan,countSol  =  1055 1630
# countScan,countSol  =  1056 1630
# countScan,countSol  =  1057 1632
# countScan,countSol  =  1058 1632
# countScan,countSol  =  1059 1632
# countScan,countSol  =  1060 1632
# countScan,countSol  =  1061 1632
# countScan,countSol  =  1062 1633
# countScan,countSol  =  1063 1633
# countScan,countSol  =  1064 1636
# countScan,countSol  =  1065 1636
# countScan,countSol  =  1066 1636
# countScan,countSol  =  1067 1636
# countScan,countSol  =  1068 1636
# countScan,countSol  =  1069 1638
# countScan,countSol  =  1070 1639
# countScan,countSol  =  1071 1640
# countScan,countSol  =  1072 1640
# countScan,countSol  =  1073 1644
# countScan,countSol  =  1074 1644
# countScan,countSol  =  1075 1644
# countScan,countSol  =  1076 1644
# countScan,countSol  =  1077 1644
# countScan,countSol  =  1078 1648
# countScan,countSol  =  1079 1650
# countScan,countSol  =  1080 1650
# countScan,countSol  =  1081 1650
# countScan,countSol  =  1082 1650
# countScan,countSol  =  1083 1650
# countScan,countSol  =  1084 1650
# countScan,countSol  =  1085 1651
# countScan,countSol  =  1086 1651
# countScan,countSol  =  1087 1652
# countScan,countSol  =  1088 1653
# countScan,countSol  =  1089 1653
# countScan,countSol  =  1090 1653
# countScan,countSol  =  1091 1653
# countScan,countSol  =  1092 1653
# countScan,countSol  =  1093 1653
# countScan,countSol  =  1094 1653
# countScan,countSol  =  1095 1653
# countScan,countSol  =  1096 1653
# countScan,countSol  =  1097 1653
# countScan,countSol  =  1098 1653
# countScan,countSol  =  1099 1655
# countScan,countSol  =  1100 1656
# countScan,countSol  =  1101 1656
# countScan,countSol  =  1102 1656
# countScan,countSol  =  1103 1656
# countScan,countSol  =  1104 1656
# countScan,countSol  =  1105 1656
# countScan,countSol  =  1106 1656
# countScan,countSol  =  1107 1656
# countScan,countSol  =  1108 1657
# countScan,countSol  =  1109 1657
# countScan,countSol  =  1110 1657
# countScan,countSol  =  1111 1658
# countScan,countSol  =  1112 1659
# countScan,countSol  =  1113 1660
# countScan,countSol  =  1114 1660
# countScan,countSol  =  1115 1660
# countScan,countSol  =  1116 1660
# countScan,countSol  =  1117 1662
# countScan,countSol  =  1118 1662
# countScan,countSol  =  1119 1662
# countScan,countSol  =  1120 1662
# countScan,countSol  =  1121 1662
# countScan,countSol  =  1122 1662
# countScan,countSol  =  1123 1663
# countScan,countSol  =  1124 1664
# countScan,countSol  =  1125 1664
# countScan,countSol  =  1126 1664
# countScan,countSol  =  1127 1664
# countScan,countSol  =  1128 1664
# countScan,countSol  =  1129 1665
# countScan,countSol  =  1130 1665
# countScan,countSol  =  1131 1667
# countScan,countSol  =  1132 1667
# countScan,countSol  =  1133 1667
# countScan,countSol  =  1134 1667
# countScan,countSol  =  1135 1667
# countScan,countSol  =  1136 1667
# countScan,countSol  =  1137 1667
# countScan,countSol  =  1138 1667
# countScan,countSol  =  1139 1668
# countScan,countSol  =  1140 1668
# countScan,countSol  =  1141 1668
# countScan,countSol  =  1142 1668
# countScan,countSol  =  1143 1669
# countScan,countSol  =  1144 1669
# countScan,countSol  =  1145 1669
# countScan,countSol  =  1146 1669
# countScan,countSol  =  1147 1669
# countScan,countSol  =  1148 1669
# countScan,countSol  =  1149 1670
# countScan,countSol  =  1150 1670
# countScan,countSol  =  1151 1670
# countScan,countSol  =  1152 1670
# countScan,countSol  =  1153 1671
# countScan,countSol  =  1154 1671
# countScan,countSol  =  1155 1671
# countScan,countSol  =  1156 1672
# countScan,countSol  =  1157 1673
# countScan,countSol  =  1158 1674
# countScan,countSol  =  1159 1675
# countScan,countSol  =  1160 1677
# countScan,countSol  =  1161 1679
# countScan,countSol  =  1162 1680
# countScan,countSol  =  1163 1682
# countScan,countSol  =  1164 1683
# countScan,countSol  =  1165 1685
# countScan,countSol  =  1166 1688
# countScan,countSol  =  1167 1691
# countScan,countSol  =  1168 1691
# countScan,countSol  =  1169 1691
# countScan,countSol  =  1170 1692
# countScan,countSol  =  1171 1692
# countScan,countSol  =  1172 1693
# countScan,countSol  =  1173 1694
# countScan,countSol  =  1174 1695
# countScan,countSol  =  1175 1696
# countScan,countSol  =  1176 1698
# countScan,countSol  =  1177 1700
# countScan,countSol  =  1178 1701
# countScan,countSol  =  1179 1703
# countScan,countSol  =  1180 1704
# countScan,countSol  =  1181 1706
# countScan,countSol  =  1182 1709
# countScan,countSol  =  1183 1712
# countScan,countSol  =  1184 1712
# countScan,countSol  =  1185 1712
# countScan,countSol  =  1186 1713
# countScan,countSol  =  1187 1713
# countScan,countSol  =  1188 1717
# countScan,countSol  =  1189 1721
# countScan,countSol  =  1190 1725
# countScan,countSol  =  1191 1729
# countScan,countSol  =  1192 1733
# countScan,countSol  =  1193 1737
# countScan,countSol  =  1194 1741
# countScan,countSol  =  1195 1744
# countScan,countSol  =  1196 1748
# countScan,countSol  =  1197 1751
# countScan,countSol  =  1198 1754
# countScan,countSol  =  1199 1757
# countScan,countSol  =  1200 1760
# countScan,countSol  =  1201 1763
# countScan,countSol  =  1202 1764
# countScan,countSol  =  1203 1767
# countScan,countSol  =  1204 1768
# countScan,countSol  =  1205 1770
# countScan,countSol  =  1206 1772
# countScan,countSol  =  1207 1773
# countScan,countSol  =  1208 1774
# countScan,countSol  =  1209 1775
# countScan,countSol  =  1210 1776
# countScan,countSol  =  1211 1776
# countScan,countSol  =  1212 1776
# countScan,countSol  =  1213 1776
# countScan,countSol  =  1214 1776
# countScan,countSol  =  1215 1776
# countScan,countSol  =  1216 1777
# countScan,countSol  =  1217 1779
# countScan,countSol  =  1218 1780
# countScan,countSol  =  1219 1780
# countScan,countSol  =  1220 1781
# countScan,countSol  =  1221 1785
# countScan,countSol  =  1222 1786
# countScan,countSol  =  1223 1788
# countScan,countSol  =  1224 1789
# countScan,countSol  =  1225 1790
# countScan,countSol  =  1226 1790
# countScan,countSol  =  1227 1792
# countScan,countSol  =  1228 1793
# countScan,countSol  =  1229 1794
# countScan,countSol  =  1230 1795
# countScan,countSol  =  1231 1795
# countScan,countSol  =  1232 1795
# countScan,countSol  =  1233 1795
# countScan,countSol  =  1234 1797
# countScan,countSol  =  1235 1797
# countScan,countSol  =  1236 1798
# countScan,countSol  =  1237 1800
# countScan,countSol  =  1238 1801
# countScan,countSol  =  1239 1801
# countScan,countSol  =  1240 1802
# countScan,countSol  =  1241 1804
# countScan,countSol  =  1242 1812
# countScan,countSol  =  1243 1814
# countScan,countSol  =  1244 1819
# countScan,countSol  =  1245 1820
# countScan,countSol  =  1246 1821
# countScan,countSol  =  1247 1821
# countScan,countSol  =  1248 1822
# countScan,countSol  =  1249 1823
# countScan,countSol  =  1250 1824
# countScan,countSol  =  1251 1828
# countScan,countSol  =  1252 1829
# countScan,countSol  =  1253 1832
# countScan,countSol  =  1254 1832
# countScan,countSol  =  1255 1833
# countScan,countSol  =  1256 1834
# countScan,countSol  =  1257 1834
# countScan,countSol  =  1258 1834
# countScan,countSol  =  1259 1835
# countScan,countSol  =  1260 1835
# countScan,countSol  =  1261 1835
# countScan,countSol  =  1262 1836
# countScan,countSol  =  1263 1838
# countScan,countSol  =  1264 1846
# countScan,countSol  =  1265 1852
# countScan,countSol  =  1266 1853
# countScan,countSol  =  1267 1854
# countScan,countSol  =  1268 1855
# countScan,countSol  =  1269 1856
# countScan,countSol  =  1270 1857
# countScan,countSol  =  1271 1858
# countScan,countSol  =  1272 1858
# countScan,countSol  =  1273 1859
# countScan,countSol  =  1274 1863
# countScan,countSol  =  1275 1864
# countScan,countSol  =  1276 1867
# countScan,countSol  =  1277 1867
# countScan,countSol  =  1278 1867
# countScan,countSol  =  1279 1868
# countScan,countSol  =  1280 1868
# countScan,countSol  =  1281 1869
# countScan,countSol  =  1282 1869
# countScan,countSol  =  1283 1869
# countScan,countSol  =  1284 1878
# countScan,countSol  =  1285 1884
# countScan,countSol  =  1286 1890
# countScan,countSol  =  1287 1896
# countScan,countSol  =  1288 1900
# countScan,countSol  =  1289 1905
# countScan,countSol  =  1290 1910
# countScan,countSol  =  1291 1913
# countScan,countSol  =  1292 1917
# countScan,countSol  =  1293 1920
# countScan,countSol  =  1294 1922
# countScan,countSol  =  1295 1924
# countScan,countSol  =  1296 1925
# countScan,countSol  =  1297 1926
# countScan,countSol  =  1298 1929
# countScan,countSol  =  1299 1930
# countScan,countSol  =  1300 1930
# countScan,countSol  =  1301 1931
# countScan,countSol  =  1302 1931
# countScan,countSol  =  1303 1932
# countScan,countSol  =  1304 1933
# countScan,countSol  =  1305 1937
# countScan,countSol  =  1306 1939
# countScan,countSol  =  1307 1940
# countScan,countSol  =  1308 1941
# countScan,countSol  =  1309 1941
# countScan,countSol  =  1310 1941
# countScan,countSol  =  1311 1943
# countScan,countSol  =  1312 1943
# countScan,countSol  =  1313 1945
# countScan,countSol  =  1314 1946
# countScan,countSol  =  1315 1947
# countScan,countSol  =  1316 1948
# countScan,countSol  =  1317 1948
# countScan,countSol  =  1318 1948
# countScan,countSol  =  1319 1949
# countScan,countSol  =  1320 1951
# countScan,countSol  =  1321 1952
# countScan,countSol  =  1322 1952
# countScan,countSol  =  1323 1955
# countScan,countSol  =  1324 1957
# countScan,countSol  =  1325 1958
# countScan,countSol  =  1326 1958
# countScan,countSol  =  1327 1960
# countScan,countSol  =  1328 1961
# countScan,countSol  =  1329 1963
# countScan,countSol  =  1330 1964
# countScan,countSol  =  1331 1965
# countScan,countSol  =  1332 1966
# countScan,countSol  =  1333 1966
# countScan,countSol  =  1334 1966
# countScan,countSol  =  1335 1966
# countScan,countSol  =  1336 1968
# countScan,countSol  =  1337 1968
# countScan,countSol  =  1338 1969
# countScan,countSol  =  1339 1971
# countScan,countSol  =  1340 1972
# ...
# countScan,countSol  =  227 0
# countScan,countSol  =  228 0
# countScan,countSol  =  229 0
# countScan,countSol  =  230 0
# countScan,countSol  =  231 0
# countScan,countSol  =  232 0
# countScan,countSol  =  233 0
# countScan,countSol  =  234 0
# countScan,countSol  =  235 0
# countScan,countSol  =  236 0
# countScan,countSol  =  237 0
# countScan,countSol  =  238 0
# countScan,countSol  =  239 0
# countScan,countSol  =  240 0
# countScan,countSol  =  241 0
# countScan,countSol  =  242 0
# countScan,countSol  =  243 0
# countScan,countSol  =  244 0
# countScan,countSol  =  245 0
# countScan,countSol  =  246 0
# countScan,countSol  =  247 0
# countScan,countSol  =  248 0
# countScan,countSol  =  249 0
# countScan,countSol  =  250 0
# countScan,countSol  =  251 0
# countScan,countSol  =  252 0
# countScan,countSol  =  253 0
# countScan,countSol  =  254 0
# countScan,countSol  =  255 0
# countScan,countSol  =  256 0
# countScan,countSol  =  257 0
# countScan,countSol  =  258 0
# countScan,countSol  =  259 0
# countScan,countSol  =  260 0
# countScan,countSol  =  261 0
# countScan,countSol  =  262 0
# countScan,countSol  =  263 0
# countScan,countSol  =  264 0
# countScan,countSol  =  265 0
# countScan,countSol  =  266 0
# countScan,countSol  =  267 0
# countScan,countSol  =  268 0
# countScan,countSol  =  269 0
# countScan,countSol  =  270 0
# countScan,countSol  =  271 0
# countScan,countSol  =  272 0
# countScan,countSol  =  273 0
# countScan,countSol  =  274 0
# countScan,countSol  =  275 0
# countScan,countSol  =  276 0
# countScan,countSol  =  277 0
# countScan,countSol  =  278 0
# countScan,countSol  =  279 0
# countScan,countSol  =  280 0
# countScan,countSol  =  281 0
# countScan,countSol  =  282 0
# countScan,countSol  =  283 0
# countScan,countSol  =  284 0
# countScan,countSol  =  285 0
# countScan,countSol  =  286 0
# countScan,countSol  =  287 0
# countScan,countSol  =  288 0
# countScan,countSol  =  289 0
# countScan,countSol  =  290 0
# countScan,countSol  =  291 0
# countScan,countSol  =  292 0
# countScan,countSol  =  293 0
# countScan,countSol  =  294 0
# countScan,countSol  =  295 0
# countScan,countSol  =  296 0
# countScan,countSol  =  297 0
# countScan,countSol  =  298 0
# countScan,countSol  =  299 0
# countScan,countSol  =  300 0
# countScan,countSol  =  301 0
# countScan,countSol  =  302 0
# countScan,countSol  =  303 0
# countScan,countSol  =  304 0
# countScan,countSol  =  305 0
# countScan,countSol  =  306 0
# countScan,countSol  =  307 0
# countScan,countSol  =  308 0
# countScan,countSol  =  309 0
# countScan,countSol  =  310 0
# countScan,countSol  =  311 0
# countScan,countSol  =  312 0
# countScan,countSol  =  313 0
# countScan,countSol  =  314 0
# countScan,countSol  =  315 0
# countScan,countSol  =  316 0
# countScan,countSol  =  317 0
# countScan,countSol  =  318 0
# countScan,countSol  =  319 0
# countScan,countSol  =  320 0
# countScan,countSol  =  321 0
# countScan,countSol  =  322 0
# countScan,countSol  =  323 0
# countScan,countSol  =  324 0
# countScan,countSol  =  325 0
# countScan,countSol  =  326 0
# countScan,countSol  =  327 0
# countScan,countSol  =  328 0
# countScan,countSol  =  329 0
# countScan,countSol  =  330 0
# countScan,countSol  =  331 0
# countScan,countSol  =  332 0
# countScan,countSol  =  333 0
# countScan,countSol  =  334 0
# countScan,countSol  =  335 0
# countScan,countSol  =  336 0
# countScan,countSol  =  337 0
# countScan,countSol  =  338 0
# countScan,countSol  =  339 0
# countScan,countSol  =  340 0
# countScan,countSol  =  341 0
# countScan,countSol  =  342 0
# countScan,countSol  =  343 0
# countScan,countSol  =  344 0
# countScan,countSol  =  345 0
# countScan,countSol  =  346 0
# countScan,countSol  =  347 0
# countScan,countSol  =  348 0
# countScan,countSol  =  349 0
# countScan,countSol  =  350 0
# countScan,countSol  =  351 0
# countScan,countSol  =  352 0
# countScan,countSol  =  353 0
# countScan,countSol  =  354 0
# countScan,countSol  =  355 0
# countScan,countSol  =  356 0
# countScan,countSol  =  357 0
# countScan,countSol  =  358 0
# countScan,countSol  =  359 0
# countScan,countSol  =  360 0
# countScan,countSol  =  361 0
# countScan,countSol  =  362 0
# countScan,countSol  =  363 0
# countScan,countSol  =  364 0
# countScan,countSol  =  365 0
# countScan,countSol  =  366 0
# countScan,countSol  =  367 0
# countScan,countSol  =  368 0
# countScan,countSol  =  369 0
# countScan,countSol  =  370 0
# countScan,countSol  =  371 0
# countScan,countSol  =  372 0
# countScan,countSol  =  373 0
# countScan,countSol  =  374 0
# countScan,countSol  =  375 0
# countScan,countSol  =  376 0
# countScan,countSol  =  377 0
# countScan,countSol  =  378 0
# countScan,countSol  =  379 0
# countScan,countSol  =  380 0
# countScan,countSol  =  381 0
# countScan,countSol  =  382 0
# countScan,countSol  =  383 0
# countScan,countSol  =  384 0
# countScan,countSol  =  385 0
# countScan,countSol  =  386 0
# countScan,countSol  =  387 0
# countScan,countSol  =  388 0
# countScan,countSol  =  389 0
# countScan,countSol  =  390 0
# countScan,countSol  =  391 0
# countScan,countSol  =  392 0
# countScan,countSol  =  393 0
# countScan,countSol  =  394 0
# countScan,countSol  =  395 0
# countScan,countSol  =  396 0
# countScan,countSol  =  397 0
# countScan,countSol  =  398 0
# countScan,countSol  =  399 0
# countScan,countSol  =  400 0
# countScan,countSol  =  401 0
# countScan,countSol  =  402 0
# countScan,countSol  =  403 0
# countScan,countSol  =  404 0
# countScan,countSol  =  405 0
# countScan,countSol  =  406 0
# countScan,countSol  =  407 0
# countScan,countSol  =  408 0
# countScan,countSol  =  409 0
# countScan,countSol  =  410 0
# countScan,countSol  =  411 0
# countScan,countSol  =  412 0
# countScan,countSol  =  413 0
# countScan,countSol  =  414 0
# countScan,countSol  =  415 0
# countScan,countSol  =  416 0
# countScan,countSol  =  417 0
# countScan,countSol  =  418 0
# countScan,countSol  =  419 0
# countScan,countSol  =  420 0
# countScan,countSol  =  421 0
# countScan,countSol  =  422 0
# countScan,countSol  =  423 0
# countScan,countSol  =  424 0
# countScan,countSol  =  425 0
# countScan,countSol  =  426 0
# countScan,countSol  =  427 0
# countScan,countSol  =  428 0
# countScan,countSol  =  429 0
# countScan,countSol  =  430 0
# countScan,countSol  =  431 0
# countScan,countSol  =  432 0
# countScan,countSol  =  433 0
# countScan,countSol  =  434 0
# countScan,countSol  =  435 0
# countScan,countSol  =  436 0
# countScan,countSol  =  437 0
# countScan,countSol  =  438 0
# countScan,countSol  =  439 0
# countScan,countSol  =  440 0
# countScan,countSol  =  441 0
# countScan,countSol  =  442 0
# countScan,countSol  =  443 0
# countScan,countSol  =  444 0
# countScan,countSol  =  445 0
# countScan,countSol  =  446 0
# countScan,countSol  =  447 0
# countScan,countSol  =  448 0
# countScan,countSol  =  449 0
# countScan,countSol  =  450 0
# countScan,countSol  =  451 0
# countScan,countSol  =  452 0
# countScan,countSol  =  453 0
# countScan,countSol  =  454 0
# countScan,countSol  =  455 0
# countScan,countSol  =  456 0
# countScan,countSol  =  457 0
# countScan,countSol  =  458 0
# countScan,countSol  =  459 0
# countScan,countSol  =  460 0
# countScan,countSol  =  461 0
# countScan,countSol  =  462 0
# countScan,countSol  =  463 0
# countScan,countSol  =  464 0
# countScan,countSol  =  465 0
# countScan,countSol  =  466 0
# countScan,countSol  =  467 0
# countScan,countSol  =  468 0
# countScan,countSol  =  469 0
# countScan,countSol  =  470 0
# countScan,countSol  =  471 0
# countScan,countSol  =  472 0
# countScan,countSol  =  473 0
# countScan,countSol  =  474 0
# countScan,countSol  =  475 0
# countScan,countSol  =  476 0
# countScan,countSol  =  477 0
# countScan,countSol  =  478 0
# countScan,countSol  =  479 0
# countScan,countSol  =  480 0
# countScan,countSol  =  481 0
# countScan,countSol  =  482 0
# countScan,countSol  =  483 0
# countScan,countSol  =  484 0
# countScan,countSol  =  485 0
# countScan,countSol  =  486 0
# countScan,countSol  =  487 0
# countScan,countSol  =  488 0
# countScan,countSol  =  489 0
# countScan,countSol  =  490 0
# countScan,countSol  =  491 0
# countScan,countSol  =  492 0
# countScan,countSol  =  493 0
# countScan,countSol  =  494 0
# countScan,countSol  =  495 0
# countScan,countSol  =  496 0
# countScan,countSol  =  497 0
# countScan,countSol  =  498 0
# countScan,countSol  =  499 0
# countScan,countSol  =  500 0
# countScan,countSol  =  501 0
# countScan,countSol  =  502 0
# countScan,countSol  =  503 0
# countScan,countSol  =  504 0
# countScan,countSol  =  505 0
# countScan,countSol  =  506 0
# countScan,countSol  =  507 0
# countScan,countSol  =  508 0
# countScan,countSol  =  509 0
# countScan,countSol  =  510 0
# countScan,countSol  =  511 0
# countScan,countSol  =  512 0
# countScan,countSol  =  513 0
# countScan,countSol  =  514 0
# countScan,countSol  =  515 0
# countScan,countSol  =  516 0
# countScan,countSol  =  517 0
# countScan,countSol  =  518 0
# countScan,countSol  =  519 0
# countScan,countSol  =  520 0
# countScan,countSol  =  521 0
# countScan,countSol  =  522 0
# countScan,countSol  =  523 0
# countScan,countSol  =  524 0
# countScan,countSol  =  525 0
# countScan,countSol  =  526 0
# countScan,countSol  =  527 0
# countScan,countSol  =  528 0
# countScan,countSol  =  529 0
# countScan,countSol  =  530 0
# countScan,countSol  =  531 0
# countScan,countSol  =  532 0
# countScan,countSol  =  533 0
# countScan,countSol  =  534 0
# countScan,countSol  =  535 0
# countScan,countSol  =  536 0
# countScan,countSol  =  537 0
# countScan,countSol  =  538 0
# countScan,countSol  =  539 0
# countScan,countSol  =  540 0
# countScan,countSol  =  541 0
# countScan,countSol  =  542 0
# countScan,countSol  =  543 0
# countScan,countSol  =  544 0
# countScan,countSol  =  545 0
# countScan,countSol  =  546 0
# countScan,countSol  =  547 0
# countScan,countSol  =  548 0
# countScan,countSol  =  549 0
# countScan,countSol  =  550 0
# countScan,countSol  =  551 0
# countScan,countSol  =  552 0
# countScan,countSol  =  553 0
# countScan,countSol  =  554 0
# countScan,countSol  =  555 0
# countScan,countSol  =  556 0
# countScan,countSol  =  557 0
# countScan,countSol  =  558 0
# countScan,countSol  =  559 0
# countScan,countSol  =  560 0
# countScan,countSol  =  561 0
# countScan,countSol  =  562 0
# countScan,countSol  =  563 0
# countScan,countSol  =  564 0
# countScan,countSol  =  565 0
# countScan,countSol  =  566 0
# countScan,countSol  =  567 0
# countScan,countSol  =  568 0
# countScan,countSol  =  569 0
# countScan,countSol  =  570 0
# countScan,countSol  =  571 0
# countScan,countSol  =  572 0
# countScan,countSol  =  573 0
# countScan,countSol  =  574 0
# countScan,countSol  =  575 0
# countScan,countSol  =  576 0
# countScan,countSol  =  577 0
# countScan,countSol  =  578 0
# countScan,countSol  =  579 0
# countScan,countSol  =  580 0
# countScan,countSol  =  581 0
# countScan,countSol  =  582 0
# countScan,countSol  =  583 0
# countScan,countSol  =  584 0
# countScan,countSol  =  585 0
# countScan,countSol  =  586 0
# countScan,countSol  =  587 0
# countScan,countSol  =  588 0
# countScan,countSol  =  589 0
# countScan,countSol  =  590 0
# countScan,countSol  =  591 0
# countScan,countSol  =  592 0
# countScan,countSol  =  593 0
# countScan,countSol  =  594 0
# countScan,countSol  =  595 0
# countScan,countSol  =  596 0
# countScan,countSol  =  597 0
# countScan,countSol  =  598 0
# countScan,countSol  =  599 0
# countScan,countSol  =  600 0
# countScan,countSol  =  601 0
# countScan,countSol  =  602 0
# countScan,countSol  =  603 0
# countScan,countSol  =  604 0
# countScan,countSol  =  605 0
# countScan,countSol  =  606 0
# countScan,countSol  =  607 0
# countScan,countSol  =  608 0
# countScan,countSol  =  609 0
# countScan,countSol  =  610 0
# countScan,countSol  =  611 0
# countScan,countSol  =  612 0
# countScan,countSol  =  613 0
# countScan,countSol  =  614 0
# countScan,countSol  =  615 0
# countScan,countSol  =  616 0
# countScan,countSol  =  617 0
# countScan,countSol  =  618 0
# countScan,countSol  =  619 0
# countScan,countSol  =  620 0
# countScan,countSol  =  621 0
# countScan,countSol  =  622 0
# countScan,countSol  =  623 0
# countScan,countSol  =  624 0
# countScan,countSol  =  625 0
# countScan,countSol  =  626 0
# countScan,countSol  =  627 0
# countScan,countSol  =  628 0
# countScan,countSol  =  629 0
# countScan,countSol  =  630 0
# countScan,countSol  =  631 0
# countScan,countSol  =  632 0
# countScan,countSol  =  633 0
# countScan,countSol  =  634 0
# countScan,countSol  =  635 0
# countScan,countSol  =  636 0
# countScan,countSol  =  637 0
# countScan,countSol  =  638 0
# countScan,countSol  =  639 0
# countScan,countSol  =  640 0
# countScan,countSol  =  641 0
# countScan,countSol  =  642 0
# countScan,countSol  =  643 0
# countScan,countSol  =  644 0
# countScan,countSol  =  645 0
# countScan,countSol  =  646 0
# countScan,countSol  =  647 0
# countScan,countSol  =  648 0
# countScan,countSol  =  649 0
# countScan,countSol  =  650 0
# countScan,countSol  =  651 0
# countScan,countSol  =  652 0
# countScan,countSol  =  653 0
# countScan,countSol  =  654 0
# countScan,countSol  =  655 0
# countScan,countSol  =  656 0
# countScan,countSol  =  657 0
# countScan,countSol  =  658 0
# countScan,countSol  =  659 0
# countScan,countSol  =  660 0
# countScan,countSol  =  661 0
# countScan,countSol  =  662 0
# countScan,countSol  =  663 0
# countScan,countSol  =  664 0
# countScan,countSol  =  665 0
# countScan,countSol  =  666 0
# countScan,countSol  =  667 0
# countScan,countSol  =  668 0
# countScan,countSol  =  669 0
# countScan,countSol  =  670 0
# countScan,countSol  =  671 0
# countScan,countSol  =  672 0
# countScan,countSol  =  673 0
# countScan,countSol  =  674 0
# countScan,countSol  =  675 0
# countScan,countSol  =  676 0
# countScan,countSol  =  677 0
# countScan,countSol  =  678 0
# countScan,countSol  =  679 0
# countScan,countSol  =  680 0
# countScan,countSol  =  681 0
# countScan,countSol  =  682 0
# countScan,countSol  =  683 0
# countScan,countSol  =  684 0
# countScan,countSol  =  685 0
# countScan,countSol  =  686 0
# countScan,countSol  =  687 0
# countScan,countSol  =  688 0
# countScan,countSol  =  689 0
# countScan,countSol  =  690 0
# countScan,countSol  =  691 0
# countScan,countSol  =  692 0
# countScan,countSol  =  693 0
# countScan,countSol  =  694 0
# countScan,countSol  =  695 0
# countScan,countSol  =  696 0
# countScan,countSol  =  697 0
# countScan,countSol  =  698 0
# countScan,countSol  =  699 0
# countScan,countSol  =  700 0
# countScan,countSol  =  701 0
# countScan,countSol  =  702 0
# countScan,countSol  =  703 0
# countScan,countSol  =  704 0
# countScan,countSol  =  705 0
# countScan,countSol  =  706 0
# countScan,countSol  =  707 0
# countScan,countSol  =  708 0
# countScan,countSol  =  709 0
# countScan,countSol  =  710 0
# countScan,countSol  =  711 0
# countScan,countSol  =  712 0
# countScan,countSol  =  713 0
# countScan,countSol  =  714 0
# countScan,countSol  =  715 0
# countScan,countSol  =  716 0
# countScan,countSol  =  717 0
# countScan,countSol  =  718 0
# countScan,countSol  =  719 0
# countScan,countSol  =  720 0
# countScan,countSol  =  721 0
# countScan,countSol  =  722 0
# countScan,countSol  =  723 0
# countScan,countSol  =  724 0
# countScan,countSol  =  725 0
# countScan,countSol  =  726 0
# countScan,countSol  =  727 0
# countScan,countSol  =  728 0
# countScan,countSol  =  729 0
# countScan,countSol  =  730 0
# countScan,countSol  =  731 0
# countScan,countSol  =  732 0
# countScan,countSol  =  733 0
# countScan,countSol  =  734 0
# countScan,countSol  =  735 0
# countScan,countSol  =  736 0
# countScan,countSol  =  737 0
# countScan,countSol  =  738 0
# countScan,countSol  =  739 0
# countScan,countSol  =  740 0
# countScan,countSol  =  741 0
# countScan,countSol  =  742 0
# countScan,countSol  =  743 0
# countScan,countSol  =  744 0
# countScan,countSol  =  745 0
# countScan,countSol  =  746 0
# countScan,countSol  =  747 0
# countScan,countSol  =  748 0
# countScan,countSol  =  749 0
# countScan,countSol  =  750 0
# countScan,countSol  =  751 0
# countScan,countSol  =  752 0
# countScan,countSol  =  753 0
# countScan,countSol  =  754 0
# countScan,countSol  =  755 0
# countScan,countSol  =  756 0
# countScan,countSol  =  757 0
# countScan,countSol  =  758 0
# countScan,countSol  =  759 0
# countScan,countSol  =  760 0
# countScan,countSol  =  761 0
# countScan,countSol  =  762 0
# countScan,countSol  =  763 0
# countScan,countSol  =  764 0
# countScan,countSol  =  765 0
# countScan,countSol  =  766 0
# countScan,countSol  =  767 0
# countScan,countSol  =  768 0
# countScan,countSol  =  769 0
# countScan,countSol  =  770 0
# countScan,countSol  =  771 0
# countScan,countSol  =  772 0
# # of sols in line 4   = 0 []
# # of sols in line 5   = 0 []
# CPU times: user 12h 38min 19s, sys: 2min 2s, total: 12h 40min 22s
# Wall time: 12h 45min 42s
